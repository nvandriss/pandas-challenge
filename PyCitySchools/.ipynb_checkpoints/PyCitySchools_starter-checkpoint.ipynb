# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#total # of schools
total_schools = len(school_data_complete["School ID"].unique())
total_schools
# Out:
# 15

# %%
#total # of students
total_students = len(school_data_complete["Student ID"].unique())
total_students
# Out:
# 39170

# %%
#total budget
total_budget = school_data["budget"].sum()
total_budget
# Out:
# 24649428

# %%
#avg math score
avg_math_score = student_data["math_score"].mean()
avg_math_score
# Out:
# 78.98537145774827

# %%
#avg reading score
avg_read_score = student_data["reading_score"].mean()
avg_read_score
# Out:
# 81.87784018381414

# %%
#percentage of passing math
student_data["passing_math"] = student_data["math_score"] >= 70
percent_pass_math = ((student_data["passing_math"]).mean())*100
percent_pass_math
# Out:
# 74.9808526933878

# %%
#percentage of passing reading
student_data["passing_read"] = student_data["reading_score"] >= 70
percent_pass_read = ((student_data["passing_read"]).mean())*100
percent_pass_read
# Out:
# 85.80546336482001

# %%
#percentage of passing for both math & reading
percent_overall_pass = (percent_pass_read + percent_pass_math)/2
percent_overall_pass
# Out:
# 80.39315802910392

# %%
#create dataframe
district_summary = [{"Total Schools":total_schools,
                     "Total Students":total_students,
                     "Total Budget":total_budget,
                     "Average Math Score":round(avg_math_score,2),
                     "Average Reading Score":round(avg_read_score,2),
                     "% Passing Math":round(percent_pass_math,2),
                     "% Passing Reading":round(percent_pass_read,2),
                     "% Overall Passing Rate":round(percent_overall_pass,2)}]

district_summary_table = pd.DataFrame(district_summary)
district_summary_table
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428               78.99
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0                  81.88           74.98              85.81
#
#    % Overall Passing Rate
# 0                   80.39

# %%
#optional formatting
district_summary_table = pd.DataFrame(district_summary)

district_summary_table["% Overall Passing Rate"] = district_summary_table["% Overall Passing Rate"].map("{:,.2f}%".format)
district_summary_table["% Passing Math"] = district_summary_table["% Passing Math"].map("{:,.2f}%".format)
district_summary_table["% Passing Reading"] = district_summary_table["% Passing Reading"].map("{:,.2f}%".format)
district_summary_table["Total Budget"] = district_summary_table["Total Budget"].map("${:,.2f}".format)
district_summary_table["Total Students"] = district_summary_table["Total Students"].map("{:,}".format)

district_summary_table
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00               78.99
#
#    Average Reading Score % Passing Math % Passing Reading  \
# 0                  81.88         74.98%            85.81%
#
#   % Overall Passing Rate
# 0                 80.39%

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#Use school_data_complete
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete["passing_math"] = student_data["math_score"] >= 70
school_data_complete["passing_reading"] = student_data["reading_score"] >= 70

school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  passing_math  passing_read  School ID  \
# ...

# %%
#Groupby School Name
school_group = school_data_complete.groupby(["school_name"]).mean()
school_group["Per Student Budget"] = school_group["budget"]/school_group["size"]
school_group["% Passing Math"] = round(school_group["passing_math"]*100,2)
school_group["% Passing Reading"] = round(school_group["passing_read"]*100,2)
school_group["% Overall Passing Rate"] = ((round(school_group["passing_math"]+school_group["passing_read"])/2)*100)

school_group
# Out:
#                        Student ID  reading_score  math_score  passing_math  \
# school_name
# Bailey High School        20358.5      81.033963   77.048432      0.666801
# Cabrera High School       16941.5      83.975780   83.061895      0.941335
# Figueroa High School       4391.0      81.158020   76.711767      0.659885
# Ford High School          36165.0      80.746258   77.102592      0.683096
# Griffin High School       12995.5      83.816757   83.351499      0.933924
# Hernandez High School      9944.0      80.934412   77.289752      0.667530
# Holden High School        23060.0      83.814988   83.803279      0.925059
# Huang High School          1458.0      81.182722   76.629414      0.656839
# Johnson High School       32415.0      80.966394   77.072464      0.660576
# Pena High School          23754.5      84.044699   83.839917      0.945946
# Rodriguez High School     28035.0      80.744686   76.842711      0.663666
# ...

# %%
#Merge school_group & school_data (and delete extra columns)
school_data_full = pd.merge(school_group,school_data, how="left", on = ["school_name", "school_name"])
del school_data_full["size_y"]
del school_data_full["budget_y"]
del school_data_full["Student ID"]
del school_data_full["School ID_x"]
del school_data_full["passing_reading"]

school_data_full
# Out:
#               school_name  reading_score  math_score  passing_math  \
# 0      Bailey High School      81.033963   77.048432      0.666801
# 1     Cabrera High School      83.975780   83.061895      0.941335
# 2    Figueroa High School      81.158020   76.711767      0.659885
# 3        Ford High School      80.746258   77.102592      0.683096
# 4     Griffin High School      83.816757   83.351499      0.933924
# 5   Hernandez High School      80.934412   77.289752      0.667530
# 6      Holden High School      83.814988   83.803279      0.925059
# 7       Huang High School      81.182722   76.629414      0.656839
# 8     Johnson High School      80.966394   77.072464      0.660576
# 9        Pena High School      84.044699   83.839917      0.945946
# 10  Rodriguez High School      80.744686   76.842711      0.663666
# 11    Shelton High School      83.725724   83.359455      0.938671
# 12     Thomas High School      83.848930   83.418349      0.932722
# ...

# %%
#create data frame 
school_full_dataframe = pd.DataFrame({"School Name":school_data_full["school_name"],
                                      "School Type":school_data_full["type"],
                                      "Total Students":school_data_full["size_x"],
                                      "Total School Budget":school_data_full["budget_x"],
                                      "Per Student Budget":school_data_full["Per Student Budget"],
                                      "Average Math Score":school_data_full["math_score"],
                                      "Average Reading Score":school_data_full["reading_score"],
                                      "% Passing Math":school_data_full["% Passing Math"],
                                      "% Passing Reading":school_data_full["% Passing Reading"],
                                      "% Overall Passing":school_data_full["% Overall Passing Rate"]})

#format
school_full_dataframe["Total Students"] = school_full_dataframe["Total Students"].map("{:,.0f}".format)
school_full_dataframe["Per Student Budget"] = school_full_dataframe["Per Student Budget"].map("${:,.2f}".format)
school_full_dataframe["Total School Budget"] = school_full_dataframe["Total School Budget"].map("${:,.2f}".format)
school_full_dataframe["Average Math Score"] = school_full_dataframe["Average Math Score"].map("{:,.2f}".format)
school_full_dataframe["Average Reading Score"] = school_full_dataframe["Average Reading Score"].map("{:,.2f}".format)

school_full_dataframe
# Out:
#               School Name School Type Total Students Total School Budget  \
# 0      Bailey High School    District          4,976       $3,124,928.00
# 1     Cabrera High School     Charter          1,858       $1,081,356.00
# 2    Figueroa High School    District          2,949       $1,884,411.00
# 3        Ford High School    District          2,739       $1,763,916.00
# 4     Griffin High School     Charter          1,468         $917,500.00
# 5   Hernandez High School    District          4,635       $3,022,020.00
# 6      Holden High School     Charter            427         $248,087.00
# 7       Huang High School    District          2,917       $1,910,635.00
# 8     Johnson High School    District          4,761       $3,094,650.00
# 9        Pena High School     Charter            962         $585,858.00
# 10  Rodriguez High School    District          3,999       $2,547,363.00
# 11    Shelton High School     Charter          1,761       $1,056,600.00
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
#Top 5
top_5 = school_full_dataframe.sort_values(["% Overall Passing"], ascending=False)
top_5.head()
# Out:
#             School Name School Type Total Students Total School Budget  \
# 1   Cabrera High School     Charter          1,858       $1,081,356.00
# 4   Griffin High School     Charter          1,468         $917,500.00
# 6    Holden High School     Charter            427         $248,087.00
# 9      Pena High School     Charter            962         $585,858.00
# 11  Shelton High School     Charter          1,761       $1,056,600.00
#
#    Per Student Budget Average Math Score Average Reading Score  \
# 1             $582.00              83.06                 83.98
# 4             $625.00              83.35                 83.82
# 6             $581.00              83.80                 83.81
# 9             $609.00              83.84                 84.04
# 11            $600.00              83.36                 83.73
#
#     % Passing Math  % Passing Reading  % Overall Passing
# 1            94.13              97.04              100.0
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
#Bottom 5
last_5 = school_full_dataframe.sort_values(["% Overall Passing"], ascending=True)
last_5.head()
# Out:
#              School Name School Type Total Students Total School Budget  \
# 0     Bailey High School    District          4,976       $3,124,928.00
# 2   Figueroa High School    District          2,949       $1,884,411.00
# 3       Ford High School    District          2,739       $1,763,916.00
# 5  Hernandez High School    District          4,635       $3,022,020.00
# 7      Huang High School    District          2,917       $1,910,635.00
#
#   Per Student Budget Average Math Score Average Reading Score  % Passing Math  \
# 0            $628.00              77.05                 81.03           66.68
# 2            $639.00              76.71                 81.16           65.99
# 3            $644.00              77.10                 80.75           68.31
# 5            $652.00              77.29                 80.93           66.75
# 7            $655.00              76.63                 81.18           65.68
#
#    % Passing Reading  % Overall Passing
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#Math Scores by Grade
ninth = school_data_complete.loc[school_data_complete["grade"] == "9th"]
tenth = school_data_complete.loc[school_data_complete["grade"] == "10th"]
eleventh = school_data_complete.loc[school_data_complete["grade"] == "11th"]
twelfth = school_data_complete.loc[school_data_complete["grade"] == "12th"]

math_9 = ninth.groupby("school_name")["math_score"].mean()
math_10 = tenth.groupby("school_name")["math_score"].mean()
math_11 = eleventh.groupby("school_name")["math_score"].mean()
math_12 = twelfth.groupby("school_name")["math_score"].mean()

math_school_grades = pd.DataFrame({"9th":math_9,"10th":math_10,"11th":math_11,"12th":math_12})

math_school_grades
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#Reading Score by Grade
ninth = school_data_complete.loc[school_data_complete["grade"] == "9th"]
tenth = school_data_complete.loc[school_data_complete["grade"] == "10th"]
eleventh = school_data_complete.loc[school_data_complete["grade"] == "11th"]
twelfth = school_data_complete.loc[school_data_complete["grade"] == "12th"]

read_9 = ninth.groupby("school_name")["reading_score"].mean()
read_10 = tenth.groupby("school_name")["reading_score"].mean()
read_11 = eleventh.groupby("school_name")["reading_score"].mean()
read_12 = twelfth.groupby("school_name")["reading_score"].mean()

read_school_grades = pd.DataFrame({"9th":read_9,"10th":read_10,"11th":read_11,"12th":read_12})

read_school_grades
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
#Set up bins
spend_bins = [0, 585, 615, 645, 675]
spend_range = ["<$585","$585-630", "$630-645","$645-680"]

# %%
#Group by School Spending
school_data_full["Spending Ranges (Per Student)"]=pd.cut(school_data_full["Per Student Budget"],spend_bins, labels=spend_range)

group_school_spend = school_data_full.groupby("Spending Ranges (Per Student)").mean()

#Delete extra columns
del group_school_spend['size_x']
del group_school_spend['budget_x']
del group_school_spend['Per Student Budget']
del group_school_spend['School ID_y']
del group_school_spend['passing_math']
del group_school_spend['passing_read']

group_school_spend
# Out:
#                                reading_score  math_score  % Passing Math  \
# Spending Ranges (Per Student)
# <$585                              83.933814   83.455399       93.460000
# $585-630                           83.885211   83.599686       94.230000
# $630-645                           81.891436   79.079225       75.668333
# $645-680                           81.027843   76.997210       66.163333
#
#                                % Passing Reading  % Overall Passing Rate
# Spending Ranges (Per Student)
# <$585                                  96.610000              100.000000
# $585-630                               95.900000              100.000000
# $630-645                               86.106667               66.666667
# $645-680                               81.133333               50.000000

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
#Set up bins
size_bins = [0, 1000, 2000, 5000]
size_range = ["Small(<1000)","Medium(1000-2000)", "Large(2000-5000)"]

#Group by School Size
school_data_full["School Size"]=pd.cut(school_data_full["size_x"],size_bins, labels=size_range)

group_school_size = school_data_full.groupby("School Size").mean()

del group_school_size['budget_x']
del group_school_size['Per Student Budget']
del group_school_size['School ID_y']
del group_school_size['passing_math']
del group_school_size['passing_read']

group_school_size
# Out:
#                    reading_score  math_score    size_x  % Passing Math  \
# School Size
# Small(<1000)           83.929843   83.821598   694.500        93.55000
# Medium(1000-2000)      83.864438   83.374684  1704.400        93.59800
# Large(2000-5000)       81.344493   77.746417  3657.375        69.96375
#
#                    % Passing Reading  % Overall Passing Rate
# School Size
# Small(<1000)                96.10000                  100.00
# Medium(1000-2000)           96.79000                  100.00
# Large(2000-5000)            82.76625                   56.25

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
group_school_type = school_data_full.groupby("type").mean()

del group_school_type['size_x']
del group_school_type['budget_x']
del group_school_type['Per Student Budget']
del group_school_type['School ID_y']
del group_school_type['passing_math']
del group_school_type['passing_read']

group_school_type
# Out:
#           reading_score  math_score  % Passing Math  % Passing Reading  \
# type
# Charter       83.896421   83.473852       93.620000          96.586250
# District      80.966636   76.956733       66.548571          80.798571
#
#           % Overall Passing Rate
# type
# Charter                    100.0
# District                    50.0
